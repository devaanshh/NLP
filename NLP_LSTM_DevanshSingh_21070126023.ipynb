# %% [markdown]
# NAME: Devansh Singh
#
# Batch. AIML - A2
#
# PRN. 21070126023

# %%
# !pip install nvidia-smi
# Out:
# Collecting nvidia-smi
#   Downloading nvidia_smi-0.1.3-py36-none-any.whl (11 kB)
# Requirement already satisfied: numpy>=1.16.2 in c:\users\dell\appdata\local\programs\python\python311\lib\site-packages (from nvidia-smi) (1.24.3)
# Requirement already satisfied: six>=1.12.0 in c:\users\dell\appdata\local\programs\python\python311\lib\site-packages (from nvidia-smi) (1.16.0)
# Collecting sorcery>=0.1.0 (from nvidia-smi)
#   Downloading sorcery-0.2.2-py3-none-any.whl (16 kB)
# Collecting pytest>=4.3.1 (from nvidia-smi)
#   Obtaining dependency information for pytest>=4.3.1 from https://files.pythonhosted.org/packages/df/d0/e192c4275aecabf74faa1aacd75ef700091913236ec78b1a98f62a2412ee/pytest-7.4.2-py3-none-any.whl.metadata
#   Downloading pytest-7.4.2-py3-none-any.whl.metadata (7.9 kB)
# Collecting iniconfig (from pytest>=4.3.1->nvidia-smi)
#   Downloading iniconfig-2.0.0-py3-none-any.whl (5.9 kB)
# Requirement already satisfied: packaging in c:\users\dell\appdata\local\programs\python\python311\lib\site-packages (from pytest>=4.3.1->nvidia-smi) (21.3)
# Collecting pluggy<2.0,>=0.12 (from pytest>=4.3.1->nvidia-smi)
#   Obtaining dependency information for pluggy<2.0,>=0.12 from https://files.pythonhosted.org/packages/05/b8/42ed91898d4784546c5f06c60506400548db3f7a4b3fb441cba4e5c17952/pluggy-1.3.0-py3-none-any.whl.metadata
#   Downloading pluggy-1.3.0-py3-none-any.whl.metadata (4.3 kB)
# Requirement already satisfied: colorama in c:\users\dell\appdata\local\programs\python\python311\lib\site-packages (from pytest>=4.3.1->nvidia-smi) (0.4.4)
# Requirement already satisfied: executing in c:\users\dell\appdata\local\programs\python\python311\lib\site-packages (from sorcery>=0.1.0->nvidia-smi) (1.2.0)
# Collecting littleutils>=0.2.1 (from sorcery>=0.1.0->nvidia-smi)
#   Downloading littleutils-0.2.2.tar.gz (6.6 kB)
#   Preparing metadata (setup.py): started
#   Preparing metadata (setup.py): finished with status 'done'
# Requirement already satisfied: asttokens in c:\users\dell\appdata\local\programs\python\python311\lib\site-packages (from sorcery>=0.1.0->nvidia-smi) (2.1.0)
# Requirement already satisfied: wrapt in c:\users\dell\appdata\local\programs\python\python311\lib\site-packages (from sorcery>=0.1.0->nvidia-smi) (1.15.0)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in c:\users\dell\appdata\local\programs\python\python311\lib\site-packages (from packaging->pytest>=4.3.1->nvidia-smi) (3.0.9)
# Downloading pytest-7.4.2-py3-none-any.whl (324 kB)
#    -------------------------------------- 324.5/324.5 kB 913.5 kB/s eta 0:00:00
# Downloading pluggy-1.3.0-py3-none-any.whl (18 kB)
# Building wheels for collected packages: littleutils
#   Building wheel for littleutils (setup.py): started
#   Building wheel for littleutils (setup.py): finished with status 'done'
#   Created wheel for littleutils: filename=littleutils-0.2.2-py3-none-any.whl size=7035 sha256=accbeb339a44e6d4a05dffc1a440521382a07d24a205f2719e9053045ac83903
#   Stored in directory: c:\users\dell\appdata\local\pip\cache\wheels\17\8d\65\9a39917567093c895549811c172be5d2dfb63c7e4b143e05a4
# Successfully built littleutils
# Installing collected packages: littleutils, pluggy, iniconfig, sorcery, pytest, nvidia-smi
# Successfully installed iniconfig-2.0.0 littleutils-0.2.2 nvidia-smi-0.1.3 pluggy-1.3.0 pytest-7.4.2 sorcery-0.2.2

# %%
# !nvidia-smi
# Out:
# 'nvidia-smi' is not recognized as an internal or external command,
# operable program or batch file.

# %%
# !pip install nltk
# Out:
# Collecting nltk
#   Downloading nltk-3.8.1-py3-none-any.whl (1.5 MB)
#      ---------------------------------------- 1.5/1.5 MB 1.0 MB/s eta 0:00:00
# Requirement already satisfied: click in c:\users\dell\appdata\local\programs\python\python311\lib\site-packages (from nltk) (8.1.3)
# Requirement already satisfied: joblib in c:\users\dell\appdata\local\programs\python\python311\lib\site-packages (from nltk) (1.2.0)
# Collecting regex>=2021.8.3 (from nltk)
#   Obtaining dependency information for regex>=2021.8.3 from https://files.pythonhosted.org/packages/de/cd/d80c9e284ae6c1b2172dacf0651d25b78ee1f7efbc12d74ea7b87c766263/regex-2023.8.8-cp311-cp311-win_amd64.whl.metadata
#   Downloading regex-2023.8.8-cp311-cp311-win_amd64.whl.metadata (42 kB)
#      ---------------------------------------- 42.0/42.0 kB 2.0 MB/s eta 0:00:00
# Requirement already satisfied: tqdm in c:\users\dell\appdata\local\programs\python\python311\lib\site-packages (from nltk) (4.65.0)
# Requirement already satisfied: colorama in c:\users\dell\appdata\local\programs\python\python311\lib\site-packages (from click->nltk) (0.4.4)
# Downloading regex-2023.8.8-cp311-cp311-win_amd64.whl (268 kB)
#    ---------------------------------------- 268.3/268.3 kB 2.1 MB/s eta 0:00:00
# Installing collected packages: regex, nltk
# Successfully installed nltk-3.8.1 regex-2023.8.8

# %%
import pandas as pd
import nltk
# nltk.download("all")
import spacy

from spacy.lang.en.stop_words import STOP_WORDS
from gensim.models import Word2Vec
import warnings
warnings.filterwarnings('ignore')

# %%
data = pd.read_csv("/content/review.csv")
data.head(5)
# Out:
#                                               review  rating
# 0  I like it I would recommend .... Because of co...       3
# 1  I really love in 5 days I've seen the progrès....       4
# 2   I received my order well packaged it try to stay       4
# 3  I already adheres to my 2 boxes and the result...       4
# 4  Saleswoman very serious and nice good product\...       4

# %%
print("Shape of data: ",data.shape)
data.info()
# Out:
# Shape of data:  (1106, 2)
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1106 entries, 0 to 1105
# Data columns (total 2 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   review  1106 non-null   object
#  1   rating  1106 non-null   int64
# dtypes: int64(1), object(1)
# memory usage: 17.4+ KB

# %%
# sampling data to get 10000 rows
data = data.sample(n=100)
data.head(10)
# Out:
#                                                  review  rating
# 363   I love this came out so perfect! My daughter w...       5
# 93                          Back logo was way too small       1
# 420   So cute! Can’t wait to hang them up in my craf...       5
# 983   Fits perfectly! It’s beautiful! Came quickly, ...       5
# 572   The shirt itself looks awesome! However, I nor...       3
# 366   Exactly as pictured! My parents loved the gift...       5
# 889      Measurements are off but overall nice product.       3
# 576   Delivered early and the shop was very responsi...       5
# 922   The design is beautiful, but I’m not sure if t...       5
# 1021  The decal looks great! It came with very clear...       5

# %%
print("Shape of data: ",data.shape)
data.info()
# Out:
# Shape of data:  (100, 2)
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 100 entries, 363 to 516
# Data columns (total 2 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   review  100 non-null    object
#  1   rating  100 non-null    int64
# dtypes: int64(1), object(1)
# memory usage: 2.3+ KB

# %%
# 2) DO FOLLOWING Preprocessing STEPS using NLTK or SpaCy:
#     a) Remove empty rows. Remove duplicates.
#     b) Tokenization, Lemmatization
#     b) Data Cleansing: Remove stopwords, remove symbols,remove emojis,     remove URLS, remove http tags, remove excess whitespaces.
#     c) Lower the strings, replace abbreviations, fix contractions.

# %%
# !spacy download en_core_web_sm
# Out:
# 2023-09-09 18:13:25.520877: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# Collecting en-core-web-sm==3.6.0
#   Downloading https://github.com/explosion/spacy-models/releases/download/en_core_web_sm-3.6.0/en_core_web_sm-3.6.0-py3-none-any.whl (12.8 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 12.8/12.8 MB 26.4 MB/s eta 0:00:00
# Requirement already satisfied: spacy<3.7.0,>=3.6.0 in /usr/local/lib/python3.10/dist-packages (from en-core-web-sm==3.6.0) (3.6.1)
# Requirement already satisfied: spacy-legacy<3.1.0,>=3.0.11 in /usr/local/lib/python3.10/dist-packages (from spacy<3.7.0,>=3.6.0->en-core-web-sm==3.6.0) (3.0.12)
# Requirement already satisfied: spacy-loggers<2.0.0,>=1.0.0 in /usr/local/lib/python3.10/dist-packages (from spacy<3.7.0,>=3.6.0->en-core-web-sm==3.6.0) (1.0.4)
# Requirement already satisfied: murmurhash<1.1.0,>=0.28.0 in /usr/local/lib/python3.10/dist-packages (from spacy<3.7.0,>=3.6.0->en-core-web-sm==3.6.0) (1.0.9)
# Requirement already satisfied: cymem<2.1.0,>=2.0.2 in /usr/local/lib/python3.10/dist-packages (from spacy<3.7.0,>=3.6.0->en-core-web-sm==3.6.0) (2.0.7)
# Requirement already satisfied: preshed<3.1.0,>=3.0.2 in /usr/local/lib/python3.10/dist-packages (from spacy<3.7.0,>=3.6.0->en-core-web-sm==3.6.0) (3.0.8)
# Requirement already satisfied: thinc<8.2.0,>=8.1.8 in /usr/local/lib/python3.10/dist-packages (from spacy<3.7.0,>=3.6.0->en-core-web-sm==3.6.0) (8.1.12)
# Requirement already satisfied: wasabi<1.2.0,>=0.9.1 in /usr/local/lib/python3.10/dist-packages (from spacy<3.7.0,>=3.6.0->en-core-web-sm==3.6.0) (1.1.2)
# Requirement already satisfied: srsly<3.0.0,>=2.4.3 in /usr/local/lib/python3.10/dist-packages (from spacy<3.7.0,>=3.6.0->en-core-web-sm==3.6.0) (2.4.7)
# Requirement already satisfied: catalogue<2.1.0,>=2.0.6 in /usr/local/lib/python3.10/dist-packages (from spacy<3.7.0,>=3.6.0->en-core-web-sm==3.6.0) (2.0.9)
# Requirement already satisfied: typer<0.10.0,>=0.3.0 in /usr/local/lib/python3.10/dist-packages (from spacy<3.7.0,>=3.6.0->en-core-web-sm==3.6.0) (0.9.0)
# Requirement already satisfied: pathy>=0.10.0 in /usr/local/lib/python3.10/dist-packages (from spacy<3.7.0,>=3.6.0->en-core-web-sm==3.6.0) (0.10.2)
# Requirement already satisfied: smart-open<7.0.0,>=5.2.1 in /usr/local/lib/python3.10/dist-packages (from spacy<3.7.0,>=3.6.0->en-core-web-sm==3.6.0) (6.3.0)
# Requirement already satisfied: tqdm<5.0.0,>=4.38.0 in /usr/local/lib/python3.10/dist-packages (from spacy<3.7.0,>=3.6.0->en-core-web-sm==3.6.0) (4.66.1)
# Requirement already satisfied: numpy>=1.15.0 in /usr/local/lib/python3.10/dist-packages (from spacy<3.7.0,>=3.6.0->en-core-web-sm==3.6.0) (1.23.5)
# Requirement already satisfied: requests<3.0.0,>=2.13.0 in /usr/local/lib/python3.10/dist-packages (from spacy<3.7.0,>=3.6.0->en-core-web-sm==3.6.0) (2.31.0)
# Requirement already satisfied: pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4 in /usr/local/lib/python3.10/dist-packages (from spacy<3.7.0,>=3.6.0->en-core-web-sm==3.6.0) (1.10.12)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.10/dist-packages (from spacy<3.7.0,>=3.6.0->en-core-web-sm==3.6.0) (3.1.2)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.10/dist-packages (from spacy<3.7.0,>=3.6.0->en-core-web-sm==3.6.0) (67.7.2)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from spacy<3.7.0,>=3.6.0->en-core-web-sm==3.6.0) (23.1)
# Requirement already satisfied: langcodes<4.0.0,>=3.2.0 in /usr/local/lib/python3.10/dist-packages (from spacy<3.7.0,>=3.6.0->en-core-web-sm==3.6.0) (3.3.0)
# Requirement already satisfied: typing-extensions>=4.2.0 in /usr/local/lib/python3.10/dist-packages (from pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4->spacy<3.7.0,>=3.6.0->en-core-web-sm==3.6.0) (4.5.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests<3.0.0,>=2.13.0->spacy<3.7.0,>=3.6.0->en-core-web-sm==3.6.0) (3.2.0)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests<3.0.0,>=2.13.0->spacy<3.7.0,>=3.6.0->en-core-web-sm==3.6.0) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests<3.0.0,>=2.13.0->spacy<3.7.0,>=3.6.0->en-core-web-sm==3.6.0) (2.0.4)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests<3.0.0,>=2.13.0->spacy<3.7.0,>=3.6.0->en-core-web-sm==3.6.0) (2023.7.22)
# Requirement already satisfied: blis<0.8.0,>=0.7.8 in /usr/local/lib/python3.10/dist-packages (from thinc<8.2.0,>=8.1.8->spacy<3.7.0,>=3.6.0->en-core-web-sm==3.6.0) (0.7.10)
# Requirement already satisfied: confection<1.0.0,>=0.0.1 in /usr/local/lib/python3.10/dist-packages (from thinc<8.2.0,>=8.1.8->spacy<3.7.0,>=3.6.0->en-core-web-sm==3.6.0) (0.1.2)
# Requirement already satisfied: click<9.0.0,>=7.1.1 in /usr/local/lib/python3.10/dist-packages (from typer<0.10.0,>=0.3.0->spacy<3.7.0,>=3.6.0->en-core-web-sm==3.6.0) (8.1.7)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.10/dist-packages (from jinja2->spacy<3.7.0,>=3.6.0->en-core-web-sm==3.6.0) (2.1.3)
# ✔ Download and installation successful
# You can now load the package via spacy.load('en_core_web_sm')

# %%
nlp = spacy.load('en_core_web_sm')
data['review'] = data['review'].apply(lambda x: nlp(x))

# %%
data['review'] = data['review'].apply(lambda x: [item.text for item in x])
data.head(2)
# Out:
#                                                 review  rating
# 363  [I, love, this, came, out, so, perfect, !, My,...       5
# 93                  [Back, logo, was, way, too, small]       1

# %%
data['review'] = data['review'].apply(lambda x: [item for item in x if item not in STOP_WORDS])
data.head(2)
# Out:
#                                                 review  rating
# 363  [I, love, came, perfect, !, My, daughter, happ...       5
# 93                            [Back, logo, way, small]       1

# %%
data['review'] = data['review'].apply(lambda x: [item for item in x if item.isalpha()])
data.head(2)
# Out:
#                                                 review  rating
# 363  [I, love, came, perfect, My, daughter, happy, ...       5
# 93                            [Back, logo, way, small]       1

# %%
data['review'] = data['review'].apply(lambda x: [item for item in x if "http" not in item])
data.head(4)
# Out:
#                                                 review  rating
# 363  [I, love, came, perfect, My, daughter, happy, ...       5
# 93                            [Back, logo, way, small]       1
# 420            [So, cute, Ca, wait, hang, craft, room]       5
# 983  [Fits, perfectly, It, beautiful, Came, quickly...       5

# %%
#Lowering cases
contraction_mapping = {
    "ain't": "is not",
    "aren't": "are not",
    "can't": "cannot",
    "could've": "could have",
    "couldn't": "could not",
    "didn't": "did not",
    "doesn't": "does not",
    "don't": "do not",
    "hadn't": "had not",
    "hasn't": "has not",
    "haven't": "have not",
    "he'd": "he would",
    "he'll": "he will",
    "he's": "he is",
    "I'd": "I would",
    "I'll": "I will",
    "I'm": "I am",
    "I've": "I have",
    "isn't": "is not",
    "it's": "it is",
    "let's": "let us",
    "mustn't": "must not",
    "shan't": "shall not",
    "she'd": "she would",
    "she'll": "she will",
    "she's": "she is",
    "should've": "should have",
    "shouldn't": "should not",
    "that's": "that is",
    "there's": "there is",
    "they'd": "they would",
    "they'll": "they will",
    "they're": "they are",
    "they've": "they have",
    "we'd": "we would",
    "we'll": "we will",
    "we're": "we are",
    "we've": "we have",
    "weren't": "were not",
    "what'll": "what will",
    "what're": "what are",
    "what's": "what is",
    "what've": "what have",
    "where's": "where is",
    "who'd": "who would",
    "who'll": "who will",
    "who're": "who are",
    "who's": "who is",
    "who've": "who have",
    "won't": "will not",
    "wouldn't": "would not",
    "you'd": "you would",
    "you'll": "you will",
    "you're": "you are",
    "you've": "you have",
    "'s": " is",
    "'ll": " will",
    "'d": " would",
    "'ve": " have",
    "'re": " are",
    "n't": " not",
}

data['review'] = data['review'].apply(lambda x: [contraction_mapping.get(item, item) for item in x])
data['review'] = data['review'].apply(lambda x: [item.lower() for item in x])
data.head(2)
# Out:
#                                                 review  rating
# 363  [i, love, came, perfect, my, daughter, happy, ...       5
# 93                            [back, logo, way, small]       1

# %%
# Applying LSTM model

# %%
#  For 1st set of results use:
#     a) batch_size = 4
#     b) max_sequence_length = 50
#     c) embedding_dim = 50
#     d) max_words = 10000
#     e) lstm_units = 32

# %%
# !pip install keras.preprocessing
# Out:
# Collecting keras.preprocessing
#   Downloading Keras_Preprocessing-1.1.2-py2.py3-none-any.whl (42 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 42.6/42.6 kB 1.3 MB/s eta 0:00:00
# Requirement already satisfied: numpy>=1.9.1 in /usr/local/lib/python3.10/dist-packages (from keras.preprocessing) (1.23.5)
# Requirement already satisfied: six>=1.9.0 in /usr/local/lib/python3.10/dist-packages (from keras.preprocessing) (1.16.0)
# Installing collected packages: keras.preprocessing
# Successfully installed keras.preprocessing-1.1.2

# %%
from keras.preprocessing.text import Tokenizer
from keras_preprocessing.sequence import pad_sequences
from keras.models import Sequential
from keras.layers import Dense, Embedding, LSTM, SpatialDropout1D
from keras.callbacks import EarlyStopping
from sklearn.model_selection import train_test_split

# %%
max_fatures = 100
tokenizer = Tokenizer(num_words=max_fatures, split=' ')
tokenizer.fit_on_texts(data['review'].values)
X = tokenizer.texts_to_sequences(data['review'].values)
X = pad_sequences(X)
y = pd.get_dummies(data['rating']).values
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.33, random_state=42)

# %%
print(X_train.shape, X_test.shape)
print(y_train.shape, y_test.shape)
# Out:
# (67, 29) (33, 29)
# (67, 5) (33, 5)

# %%
model_one = Sequential()
model_one.add(Embedding(max_fatures, 50, input_length=X.shape[1]))
model_one.add(SpatialDropout1D(0.4))
model_one.add(LSTM(32, dropout=0.2, recurrent_dropout=0.2))
model_one.add(Dense(5, activation='softmax'))
model_one.compile(loss='categorical_crossentropy', optimizer='adam', metrics=['accuracy'])
print(model_one.summary())
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  embedding (Embedding)       (None, 29, 50)            5000
#
#  spatial_dropout1d (Spatial  (None, 29, 50)            0
#  Dropout1D)
#
#  lstm (LSTM)                 (None, 32)                10624
#
#  dense (Dense)               (None, 5)                 165
#
# =================================================================
# Total params: 15789 (61.68 KB)
# Trainable params: 15789 (61.68 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________
# None

# %%
model_one.fit(X_train, y_train, epochs=20, batch_size=4, callbacks=[EarlyStopping(monitor='val_loss', min_delta=0.01, patience=7, restore_best_weights=True)])
# Out:
# Epoch 1/20
# 16/17 [===========================>..] - ETA: 0s - loss: 1.5080 - accuracy: 0.6719
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
# 17/17 [==============================] - 10s 53ms/step - loss: 1.4924 - accuracy: 0.6866
# Epoch 2/20
# 17/17 [==============================] - ETA: 0s - loss: 1.0621 - accuracy: 0.7612
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
# 17/17 [==============================] - 1s 69ms/step - loss: 1.0621 - accuracy: 0.7612
# Epoch 3/20
# 17/17 [==============================] - ETA: 0s - loss: 0.8746 - accuracy: 0.7612
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
# 17/17 [==============================] - 1s 69ms/step - loss: 0.8746 - accuracy: 0.7612
# Epoch 4/20
# 17/17 [==============================] - ETA: 0s - loss: 0.8315 - accuracy: 0.7612
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
# 17/17 [==============================] - 1s 71ms/step - loss: 0.8315 - accuracy: 0.7612
# Epoch 5/20
# 17/17 [==============================] - ETA: 0s - loss: 0.8292 - accuracy: 0.7612
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
# 17/17 [==============================] - 2s 101ms/step - loss: 0.8292 - accuracy: 0.7612
# Epoch 6/20
# 17/17 [==============================] - ETA: 0s - loss: 0.8059 - accuracy: 0.7612
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
# 17/17 [==============================] - 2s 95ms/step - loss: 0.8059 - accuracy: 0.7612
# Epoch 7/20
# 16/17 [===========================>..] - ETA: 0s - loss: 0.7278 - accuracy: 0.7812
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
# 17/17 [==============================] - 1s 40ms/step - loss: 0.7830 - accuracy: 0.7612
# Epoch 8/20
# 17/17 [==============================] - ETA: 0s - loss: 0.7966 - accuracy: 0.7612
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
# 17/17 [==============================] - 1s 40ms/step - loss: 0.7966 - accuracy: 0.7612
# Epoch 9/20
# 17/17 [==============================] - ETA: 0s - loss: 0.7789 - accuracy: 0.7612
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
# 17/17 [==============================] - 1s 46ms/step - loss: 0.7789 - accuracy: 0.7612
# Epoch 10/20
# 17/17 [==============================] - ETA: 0s - loss: 0.7338 - accuracy: 0.7612
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
# 17/17 [==============================] - 1s 64ms/step - loss: 0.7338 - accuracy: 0.7612
# Epoch 11/20
# 17/17 [==============================] - ETA: 0s - loss: 0.7064 - accuracy: 0.7761
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
# 17/17 [==============================] - 1s 71ms/step - loss: 0.7064 - accuracy: 0.7761
# Epoch 12/20
# 17/17 [==============================] - ETA: 0s - loss: 0.6682 - accuracy: 0.7910
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
# 17/17 [==============================] - 0s 28ms/step - loss: 0.6682 - accuracy: 0.7910
# Epoch 13/20
# 17/17 [==============================] - ETA: 0s - loss: 0.6071 - accuracy: 0.7910
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
# 17/17 [==============================] - 0s 28ms/step - loss: 0.6071 - accuracy: 0.7910
# Epoch 14/20
# 17/17 [==============================] - ETA: 0s - loss: 0.5625 - accuracy: 0.8209
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
# 17/17 [==============================] - 0s 28ms/step - loss: 0.5625 - accuracy: 0.8209
# Epoch 15/20
# 17/17 [==============================] - ETA: 0s - loss: 0.5000 - accuracy: 0.8358
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
# 17/17 [==============================] - 0s 28ms/step - loss: 0.5000 - accuracy: 0.8358
# Epoch 16/20
# 17/17 [==============================] - ETA: 0s - loss: 0.4476 - accuracy: 0.8507
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
# 17/17 [==============================] - 0s 27ms/step - loss: 0.4476 - accuracy: 0.8507
# Epoch 17/20
# 17/17 [==============================] - ETA: 0s - loss: 0.4349 - accuracy: 0.8657
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
# 17/17 [==============================] - 0s 27ms/step - loss: 0.4349 - accuracy: 0.8657
# Epoch 18/20
# 17/17 [==============================] - ETA: 0s - loss: 0.4715 - accuracy: 0.8657
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
# 17/17 [==============================] - 0s 29ms/step - loss: 0.4715 - accuracy: 0.8657
# Epoch 19/20
# 17/17 [==============================] - ETA: 0s - loss: 0.3951 - accuracy: 0.8806
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
# 17/17 [==============================] - 0s 27ms/step - loss: 0.3951 - accuracy: 0.8806
# Epoch 20/20
# 17/17 [==============================] - ETA: 0s - loss: 0.3377 - accuracy: 0.8657
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
# 17/17 [==============================] - 0s 28ms/step - loss: 0.3377 - accuracy: 0.8657

# %%
# save model
model_one.save('model_one.h5')

# %%
  # For 2st set of results use:
  #   a) batch_size = 8
  #   b) max_sequence_length = 30
  #   c) embedding_dim = 30
  #   d) max_words = 25000
  #   e) lstm_units = 32

# %%
max_features = 250
tokenizer = Tokenizer(num_words=max_features, split=' ')
tokenizer.fit_on_texts(data['review'].values)
X = tokenizer.texts_to_sequences(data['review'].values)
X = pad_sequences(X)
y = pd.get_dummies(data['rating']).values
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.33, random_state=42)

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.33, random_state=42)

# %%
print(X_train.shape, X_test.shape)
print(y_train.shape, y_test.shape)
# Out:
# (67, 52) (33, 52)
# (67, 5) (33, 5)

# %%
model_two = Sequential()
model_two.add(Embedding(max_features, 30, input_length=X.shape[1]))
model_two.add(SpatialDropout1D(0.4))
model_two.add(LSTM(32, dropout=0.2, recurrent_dropout=0.2, return_sequences=True))
model_two.add(LSTM(32, dropout=0.2, recurrent_dropout=0.2))
model_two.add(Dense(5, activation='softmax'))
model_two.compile(loss='categorical_crossentropy', optimizer='adam', metrics=['accuracy'])
print(model_two.summary())
# Out:
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  embedding_1 (Embedding)     (None, 52, 30)            750000
#
#  spatial_dropout1d_1 (Spati  (None, 52, 30)            0
#  alDropout1D)
#
#  lstm_1 (LSTM)               (None, 52, 32)            8064
#
#  lstm_2 (LSTM)               (None, 32)                8320
#
#  dense_1 (Dense)             (None, 5)                 165
#
# =================================================================
# Total params: 766549 (2.92 MB)
# Trainable params: 766549 (2.92 MB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________
# None

# %%
model_two.fit(X_train, y_train, epochs=20, batch_size=8, callbacks=[EarlyStopping(monitor='loss', min_delta=0.01, patience=7, restore_best_weights=True)])
# Out:
# Epoch 1/20
# 9/9 [==============================] - 7s 100ms/step - loss: 1.5483 - accuracy: 0.7164
# Epoch 2/20
# 9/9 [==============================] - 1s 99ms/step - loss: 1.2576 - accuracy: 0.7612
# Epoch 3/20
# 9/9 [==============================] - 1s 99ms/step - loss: 0.9744 - accuracy: 0.7612
# Epoch 4/20
# 9/9 [==============================] - 1s 102ms/step - loss: 0.8791 - accuracy: 0.7612
# Epoch 5/20
# 9/9 [==============================] - 3s 310ms/step - loss: 0.8313 - accuracy: 0.7612
# Epoch 6/20
# 9/9 [==============================] - 2s 189ms/step - loss: 0.8405 - accuracy: 0.7612
# Epoch 7/20
# 9/9 [==============================] - 2s 191ms/step - loss: 0.8081 - accuracy: 0.7612
# Epoch 8/20
# 9/9 [==============================] - 1s 100ms/step - loss: 0.7845 - accuracy: 0.7612
# Epoch 9/20
# 9/9 [==============================] - 1s 98ms/step - loss: 0.7631 - accuracy: 0.7612
# Epoch 10/20
# 9/9 [==============================] - 1s 99ms/step - loss: 0.7482 - accuracy: 0.7910
# Epoch 11/20
# 9/9 [==============================] - 1s 102ms/step - loss: 0.7105 - accuracy: 0.7761
# Epoch 12/20
# 9/9 [==============================] - 1s 101ms/step - loss: 0.6643 - accuracy: 0.7910
# Epoch 13/20
# 9/9 [==============================] - 1s 172ms/step - loss: 0.5839 - accuracy: 0.8358
# Epoch 14/20
# 9/9 [==============================] - 1s 111ms/step - loss: 0.5085 - accuracy: 0.8507
# Epoch 15/20
# 9/9 [==============================] - 1s 164ms/step - loss: 0.4577 - accuracy: 0.8507
# Epoch 16/20
# 9/9 [==============================] - 1s 143ms/step - loss: 0.4317 - accuracy: 0.8657
# Epoch 17/20
# 9/9 [==============================] - 1s 98ms/step - loss: 0.3811 - accuracy: 0.8657
# Epoch 18/20
# 9/9 [==============================] - 1s 100ms/step - loss: 0.3461 - accuracy: 0.8955
# Epoch 19/20
# 9/9 [==============================] - 1s 100ms/step - loss: 0.3461 - accuracy: 0.8806
# Epoch 20/20
# 9/9 [==============================] - 1s 100ms/step - loss: 0.3128 - accuracy: 0.8955

# %%
model_two.save('model_two.h5')

# %%
# Evaluating the model

# %% [markdown]
# ---

# %%
from keras.models import load_model
from sklearn.model_selection import train_test_split

# %%
data = pd.read_csv("/content/review.csv")
data = data.sample(n=100)

# %%
max_fatures = 100
tokenizer = Tokenizer(num_words=max_fatures, split=' ')
tokenizer.fit_on_texts(data['review'].values)
X = tokenizer.texts_to_sequences(data['review'].values)
X = pad_sequences(X, maxlen=433)
y = pd.get_dummies(data['rating']).values
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.33, random_state=42)

# %%
print(X_train.shape, X_test.shape)
print(y_train.shape, y_test.shape)
# Out:
# (67, 433) (33, 433)
# (67, 5) (33, 5)

# %%
model_one = load_model('model_one.h5', compile=False)
model_one.compile(loss='categorical_crossentropy', optimizer='adam', metrics=['accuracy'])

# %%
loss_m1, accuracy_m1 = model_one.evaluate(X_test, y_test)
print("loss of model 1: ", loss_m1, "accuracy of model 1: ", accuracy_m1)
# Out:
# 104/104 [==============================] - 4s 29ms/step - loss: 3.6179 - accuracy: 0.5642
# loss of model 1:  3.6178691387176514 accuracy of model 1:  0.564242422580719

# %%
predictions_m1 = model_one.predict(X_test)
print(predictions_m1)
# Out:
# 104/104 [==============================] - 3s 28ms/step
# [[1.0638024e-06 3.2071828e-08 8.2952107e-07 7.3840516e-07 9.9999738e-01]
#  [2.0340972e-06 4.9299075e-08 6.3931896e-07 2.2569320e-06 9.9999499e-01]
#  [1.6369984e-02 4.5352869e-02 6.3043994e-01 1.7141470e-01 1.3642256e-01]
#  ...
#  [4.4416352e-05 1.3472097e-06 1.5721776e-05 1.7671134e-04 9.9976176e-01]
#  [1.3842887e-06 2.5430678e-08 1.1531790e-06 2.3747602e-06 9.9999511e-01]
#  [8.9920559e-06 4.2243559e-07 2.3523769e-05 4.5122990e-05 9.9992192e-01]]

# %%
max_features = 25000
tokenizer = Tokenizer(num_words=max_features, split=' ')
tokenizer.fit_on_texts(data['Text'].values)
X = tokenizer.texts_to_sequences(data['Text'].values)
X = pad_sequences(X, maxlen=446)
y = pd.get_dummies(data['Score']).values
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.33, random_state=42)

# %%
model_two = load_model('model_two.h5', compile=False)
model_two.compile(loss='categorical_crossentropy', optimizer='adam', metrics=['accuracy'])
